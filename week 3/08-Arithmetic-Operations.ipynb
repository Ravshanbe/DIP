# %%
import numpy as np

a = np.ones([2], dtype = "uint8")
b = a * 100
print(b)
print(b + 155)
print(b + 160)
# Out:
# [100 100]
# [255 255]
# [4 4]

# %%
import numpy as np

m1 = np.array([[150, 155], [156, 157]], dtype = "uint8")
m2 = np.ones([2,2], dtype = "uint8") * 100
print("m1:")
print(m1)
print("m2:")
print(m2)
print("m1+m2:")
print(m1 + m2)
# Out:
# m1:
# [[150 155]
#  [156 157]]
# m2:
# [[100 100]
#  [100 100]]
# m1+m2:
# [[250 255]
#  [  0   1]]

# %%
m1 = np.array([[150, 155], [156, 157]], dtype = "uint8")
m2 = np.ones([2,2], dtype = "uint8") * 100 #or you can simply write 100

modified_m1 = m1.astype('int16') + m2
modified_m1 = np.minimum(modified_m1, 255)
modified_m1 = modified_m1.astype('uint8')
modified_m1
# Out:
# array([[250, 255],
#        [255, 255]], dtype=uint8)

# %%
import numpy as np

m1 = np.array([[150, 155], [156, 157]], dtype = "uint8")

value_to_add = 100
max_threshold = 255 - 100

m1[m1 >= max_threshold] = 255
m1[m1 < max_threshold] += value_to_add

print(m1)
# Out:
# [[250 255]
#  [255 255]]

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('/Users/ravshan/Documents/programming/DIP/week 2/image.png')

# Create a matrix of ones, then multiply it by a scaler of 100
# This gives a matrix with same dimesions of our image with all values being 100
M = np.ones(image.shape, dtype = "uint8") * 100

added = cv2.add(image, M)
subtracted = cv2.subtract(image, M)


plt.figure(figsize=[15,5])
plt.subplot(131);plt.imshow(image[...,::-1]);plt.title("Original");
plt.subplot(132);plt.imshow(added[...,::-1]);plt.title("Added");
plt.subplot(133);plt.imshow(subtracted[...,::-1]);plt.title("Subtracted");


# cv2.imshow("Original", image)
# cv2.imshow("Added", added)
# cv2.imshow("Subtracted", subtracted)

# cv2.waitKey(0)
# cv2.destroyAllWindows()

# %%
import cv2
import numpy as np

img1 = cv2.imread('/Users/ravshan/Documents/programming/DIP/images/png-transparent-black-small-apple-logo-logo-material-apple-logo-black-thumbnail.png')
shape = img1.shape
img2 = cv2.imread('/Users/ravshan/Documents/programming/DIP/week 2/image.png')[100:100+shape[0], 100:100+shape[1],:]

output_image = cv2.add(img1,img2)

plt.figure(figsize=[10,5])
plt.subplot(131);plt.imshow(img1[...,::-1]);plt.title("image1");
plt.subplot(132);plt.imshow(img2[...,::-1]);plt.title("image2");
plt.subplot(133);plt.imshow(output_image[...,::-1]);plt.title("image1+image2");

# %%
import cv2
import numpy as np

img1 = cv2.imread('/Users/ravshan/Documents/programming/DIP/images/png-transparent-black-small-apple-logo-logo-material-apple-logo-black-thumbnail.png')
img2 = cv2.imread('/Users/ravshan/Documents/programming/DIP/week 2/image.png')

print(img1.shape)
print(img2.shape)
# Out:
# (270, 360, 3)
# (1024, 1536, 3)

# %%
logo_h, logo_w, _ = img2.shape
location_h = 10
location_w = 500
padded_img2 = np.zeros_like(img1)
padded_img2[location_h:location_h+logo_h,location_w:location_w+logo_w,:] = img2
plt.imshow(padded_img2[...,::-1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 5
#       3 location_w = 500
#       4 padded_img2 = np.zeros_like(img1)
# ----> 5 padded_img2[location_h:location_h+logo_h,location_w:location_w+logo_w,:] = img2
#       6 plt.imshow(padded_img2[...,::-1])
#
# ValueError: could not broadcast input array from shape (1024,1536,3) into shape (260,0,3)

# %%
output_image = cv2.add(img1,padded_img2)
plt.imshow(output_image[...,::-1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 output_image = cv2.add(img1,padded_img2)
#       2 plt.imshow(output_image[...,::-1])
#
# NameError: name 'padded_img2' is not defined
